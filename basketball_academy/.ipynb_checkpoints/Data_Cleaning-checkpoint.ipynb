# %% [markdown]
# Now lets clean the anonymized data

# %%
import pandas as pd

# %%
df = pd.read_csv("Anonymized_Data.csv")

# %%
df
# Out:
#              Timestamp    Student ID  Aug 19  Aug 20  Aug 21  Aug 22  Aug 23  \
# 0   7/16/2024 13:31:46   DK-201112-0    True    True    True    True    True
# 1   7/16/2024 14:01:06   DC-201204-1    True    True    True    True    True
# 2   7/26/2024 13:45:05   JC-201209-1    True    True   False    True    True
# 3    7/27/2024 6:34:32   EC-201204-1    True    True   False   False    True
# 4    7/27/2024 6:36:31   EC-201410-1    True    True    True    True    True
# 5    7/30/2024 4:16:19   LM-201508-1    True    True    True   False    True
# 6    7/30/2024 6:38:05   AL-201410-1    True    True    True    True    True
# 7    7/31/2024 6:49:26   AJ-201306-1    True    True    True    True    True
# 8    8/2/2024 11:00:47  RJL-201204-1   False   False   False   False   False
# 9    8/2/2024 11:52:26  LVH-201709-1    True    True    True    True    True
# 10   8/2/2024 12:15:57   TT-201602-1    True    True   False   False    True
# ...

# %% [markdown]
# Check Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Timestamp                            30 non-null     object
#  1   Student ID                           34 non-null     object
#  2   Aug 19                               34 non-null     bool
#  3   Aug 20                               34 non-null     bool
#  4   Aug 21                               34 non-null     bool
#  5   Aug 22                               34 non-null     bool
#  6   Aug 23                               34 non-null     bool
#  7   Payment Received                     25 non-null     object
#  8   Jersey Sizes                         24 non-null     float64
#  9   Payment Date                         12 non-null     object
#  10  Date of Birth                        34 non-null     object
# ...

# %% [markdown]
# Convert data to appropriate data types

# %%
# Convert Timestamp column to datetime
df['Timestamp'] = pd.to_datetime(df['Timestamp'], format='%m/%d/%Y %H:%M:%S')
# Convert Payment Received to integer
df['Payment Received'] = df['Payment Received'].astype(str).str.replace('[$,]', '', regex=True).astype(float).astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[24], line 4
#       2 df['Timestamp'] = pd.to_datetime(df['Timestamp'], format='%m/%d/%Y %H:%M:%S')
#       3 # Convert Payment Received to integer
# ----> 4 df['Payment Received'] = df['Payment Received'].astype(str).str.replace('[$,]', '', regex=True).astype(float).astype(int)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %% [markdown]
# Check for missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Timestamp                            30 non-null     datetime64[ns]
#  1   Student ID                           34 non-null     object
#  2   Aug 19                               34 non-null     bool
#  3   Aug 20                               34 non-null     bool
#  4   Aug 21                               34 non-null     bool
#  5   Aug 22                               34 non-null     bool
#  6   Aug 23                               34 non-null     bool
#  7   Payment Received                     25 non-null     object
#  8   Jersey Sizes                         24 non-null     float64
#  9   Payment Date                         12 non-null     object
#  10  Date of Birth                        34 non-null     object
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                               4
# Student ID                              0
# Aug 19                                  0
# Aug 20                                  0
# Aug 21                                  0
# Aug 22                                  0
# Aug 23                                  0
# Payment Received                        9
# Jersey Sizes                           10
# Payment Date                           22
# Date of Birth                           0
# Age                                     4
# Gender                                  0
# School                                  4
# Age Group                              32
# Payment Instruction Acknowledgement     4
# Injury Liability Waver                  4
# Photograph Release Agreement            5
# dtype: int64

# %% [markdown]
# Lets deal with the missing information.

# %% [markdown]
# Lets fill in the null values

# %%
df
# Out:
#              Timestamp    Student ID  Aug 19  Aug 20  Aug 21  Aug 22  Aug 23  \
# 0   7/16/2024 13:31:46   DK-201112-0    True    True    True    True    True
# 1   7/16/2024 14:01:06   DC-201204-1    True    True    True    True    True
# 2   7/26/2024 13:45:05   JC-201209-1    True    True   False    True    True
# 3    7/27/2024 6:34:32   EC-201204-1    True    True   False   False    True
# 4    7/27/2024 6:36:31   EC-201410-1    True    True    True    True    True
# 5    7/30/2024 4:16:19   LM-201508-1    True    True    True   False    True
# 6    7/30/2024 6:38:05   AL-201410-1    True    True    True    True    True
# 7    7/31/2024 6:49:26   AJ-201306-1    True    True    True    True    True
# 8    8/2/2024 11:00:47  RJL-201204-1   False   False   False   False   False
# 9    8/2/2024 11:52:26  LVH-201709-1    True    True    True    True    True
# 10   8/2/2024 12:15:57   TT-201602-1    True    True   False   False    True
# ...

# %% [markdown]
# Lets count and remove individuals who didnt attend the camp.

# %%
# DNA = Did Not Attend
DNA = df[(df[['Aug 19', 'Aug 20', 'Aug 21', 'Aug 22', 'Aug 23']] == False).all(axis=1)]

# Extract the names of the participants meeting the condition
names = DNA['Student ID']
print(names)
# Out:
# 8     RJL-201204-1
# 12     NL-201811-1
# 22    TAJ-201207-0
# Name: Student ID, dtype: object

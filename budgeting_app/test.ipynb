# %%
from utils import statement_pdf_processing

# %%
statement_pdf_processing('/Users/kaiisfly/PycharmProjects/Data_Analytics_Portfolio/budgeting_app/e_statements/eStatementFile_20250107183121.pdf')
# Out:
# +--------------------+-------------+-----------------------------------------+----------+
# | Transaction Date   | Post Date   | Description                             |   Amount |
# +====================+=============+=========================================+==========+
# | 08NOV              | 07NOV       | AGODA.COM WM HOTEL H INTERNET SG        |  1396.56 |
# +--------------------+-------------+-----------------------------------------+----------+
# | 08NOV              | 06NOV       | KIKUSAN (1623) SHATIN HK                |   124.3  |
# +--------------------+-------------+-----------------------------------------+----------+
# | 08NOV              | 07NOV       | M SQUARE HongKong HK                    |   100    |
# +--------------------+-------------+-----------------------------------------+----------+
# | 09NOV              | 07NOV       | CITY SUPER LIMITED SHATIN HK            |    88    |
# ...
